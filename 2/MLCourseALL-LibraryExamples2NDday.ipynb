# %%
import numpy as np

# %%
# we need to write our library on top of our jupyter notebook(not always :P)
x1 = np.random.randint(10, size=6)  # One-dimensional array
x2 = np.random.randint(10, size=(3, 4))  # Two-dimensional array
x3 = np.random.randint(10, size=(3, 4, 5))  # Three-dimensional array
print("x3 ndimension: ", x3.ndim)
print("x3 shape:", x3.shape)
print("x3 size: ", x3.size)
x3
# Out:
# x3 ndimension:  3
# x3 shape: (3, 4, 5)
# x3 size:  60
# array([[[6, 9, 7, 8, 8],
#         [2, 7, 8, 8, 0],
#         [7, 2, 8, 2, 3],
#         [9, 1, 7, 9, 8]],
#
#        [[5, 6, 9, 2, 2],
#         [9, 1, 4, 6, 2],
#         [4, 7, 0, 3, 8],
#         [3, 0, 7, 2, 5]],
#
#        [[5, 4, 9, 9, 0],
#         [4, 4, 3, 7, 5],
#         [8, 1, 0, 6, 8],
#         [8, 8, 8, 4, 6]]])

# %%
import matplotlib.pyplot as plt

plt.plot([3, 4, 9,10,23])
plt.ylabel('my favorite numbers')
# Out:
# Text(0, 0.5, 'my favorite numbers')

# %%
import matplotlib.pyplot as plt
import numpy as np
# Fixing random state for reproducibility
x = np.arange(0.0, 50.0, 2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 30.0
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x, y, s, c="g", alpha=0.5, marker=r'$\clubsuit$',
            label="Luck")
plt.xlabel("Leprechauns")
plt.ylabel("Gold")
plt.legend(loc='upper left')
plt.show()

# %%
# Library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Basic chart
df=pd.DataFrame({'x': range(1,101), 'y': np.random.randn(100)*15+range(1,101) })
plt.plot( 'x', 'y', data=df, linestyle='none', marker='*')
 
# Annotate with text + Arrow
plt.annotate(
# Label and coordinate
'This point is interesting!', xy=(25, 50), xytext=(0, 90),
 
# Custom arrow
arrowprops=dict(facecolor='black', shrink=0.05)
)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
# Text(0, 90, 'This point is interesting!')

# %%
# Let’s study on more interesting example where we can use it
plt.plot([1,2,3,4,5], [1,2,3,4,10], 'go')
plt.plot([1,2,3,4,5], [2,3,4,5,11], 'b*')
#DEFINITION = plt.plot([PLACES OF X],[PLACES OF Y],’type of mark’)
plt.title('MY Scatterplot')   # name of your graph
plt.xlabel('X axis')  # name your x axis
plt.ylabel('Y axis')   # name your y axis
plt.show()   # this command must be in the end to show the results

# %%
# Sample Decision Tree Classifier
from sklearn import datasets
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
# load the iris datasets
dataset = datasets.load_iris()
# fit a CART model to the data
model = DecisionTreeClassifier()
model.fit(dataset.data, dataset.target)
print(model)
# make predictions
expected = dataset.target
predicted = model.predict(dataset.data)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))  ## result measurement
print(metrics.confusion_matrix(expected, predicted))
# Out:
# DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        50
#            2       1.00      1.00      1.00        50
#
#     accuracy                           1.00       150
#    macro avg       1.00      1.00      1.00       150
# weighted avg       1.00      1.00      1.00       150
#
# [[50  0  0]
#  [ 0 50  0]
#  [ 0  0 50]]

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
myData = np.random.randint(1, 9, (100 ,4)) # implement
myData # show the data
myData.shape
# Out:
# (100, 4)

# %%
scalar_model = MinMaxScaler()
scalar_model.fit_transform(myData)
# Out:
# array([[0.71428571, 0.42857143, 0.71428571, 0.28571429],
#        [0.        , 0.        , 0.14285714, 0.        ],
#        [0.42857143, 0.42857143, 0.85714286, 0.28571429],
#        [0.28571429, 0.42857143, 0.57142857, 0.        ],
#        [0.42857143, 0.85714286, 0.71428571, 0.28571429],
#        [0.42857143, 0.28571429, 0.57142857, 0.42857143],
#        [0.14285714, 0.85714286, 0.71428571, 0.14285714],
#        [0.71428571, 0.28571429, 0.28571429, 0.        ],
#        [0.85714286, 0.14285714, 1.        , 0.57142857],
#        [0.28571429, 0.85714286, 0.42857143, 0.        ],
#        [0.42857143, 0.        , 0.        , 0.        ],
#        [0.57142857, 0.        , 0.42857143, 0.85714286],
#        [1.        , 0.71428571, 0.14285714, 0.28571429],
#        [0.57142857, 0.42857143, 0.28571429, 0.85714286],
#        [1.        , 0.71428571, 0.71428571, 0.85714286],
#        [0.42857143, 0.85714286, 0.57142857, 0.        ],
#        [0.85714286, 0.28571429, 1.        , 0.14285714],
#        [0.        , 0.57142857, 0.42857143, 0.42857143],
#        [0.14285714, 0.42857143, 0.85714286, 1.        ],
#        [0.57142857, 0.85714286, 0.28571429, 0.28571429],
#        [0.85714286, 0.42857143, 0.57142857, 1.        ],
#        [0.71428571, 1.        , 0.85714286, 0.57142857],
#        [0.71428571, 0.57142857, 0.85714286, 1.        ],
#        [0.        , 0.28571429, 0.71428571, 0.28571429],
#        [0.57142857, 0.14285714, 0.14285714, 0.57142857],
#        [0.        , 1.        , 0.71428571, 0.28571429],
#        [0.85714286, 1.        , 0.        , 1.        ],
#        [0.        , 0.        , 0.42857143, 1.        ],
#        [0.14285714, 0.85714286, 1.        , 0.        ],
#        [0.28571429, 0.42857143, 0.85714286, 0.14285714],
#        [0.57142857, 0.42857143, 0.42857143, 0.71428571],
#        [0.14285714, 0.71428571, 0.71428571, 1.        ],
#        [1.        , 1.        , 0.85714286, 0.28571429],
#        [1.        , 1.        , 0.28571429, 1.        ],
#        [0.14285714, 1.        , 0.71428571, 0.57142857],
#        [0.57142857, 0.71428571, 0.85714286, 0.28571429],
#        [0.14285714, 0.42857143, 0.57142857, 0.85714286],
#        [0.71428571, 0.85714286, 0.57142857, 0.71428571],
#        [0.42857143, 0.57142857, 0.14285714, 0.28571429],
#        [0.85714286, 0.28571429, 0.85714286, 0.71428571],
#        [0.85714286, 0.71428571, 0.28571429, 0.85714286],
#        [0.        , 0.85714286, 0.28571429, 0.        ],
#        [0.85714286, 0.        , 0.71428571, 0.71428571],
#        [0.14285714, 0.42857143, 0.57142857, 0.14285714],
#        [0.28571429, 0.        , 0.71428571, 0.        ],
#        [0.71428571, 0.57142857, 0.14285714, 0.85714286],
#        [0.28571429, 0.85714286, 0.85714286, 0.85714286],
#        [0.28571429, 0.71428571, 0.14285714, 0.57142857],
#        [0.57142857, 0.14285714, 0.14285714, 0.28571429],
#        [0.85714286, 0.42857143, 0.42857143, 1.        ],
#        [0.85714286, 0.57142857, 1.        , 0.85714286],
#        [1.        , 0.14285714, 0.85714286, 0.28571429],
#        [1.        , 0.71428571, 0.42857143, 0.71428571],
#        [1.        , 1.        , 0.28571429, 0.85714286],
#        [0.28571429, 0.57142857, 0.28571429, 0.28571429],
#        [1.        , 0.57142857, 0.42857143, 0.28571429],
#        [1.        , 1.        , 0.85714286, 0.42857143],
#        [0.        , 0.85714286, 1.        , 0.57142857],
#        [0.14285714, 0.28571429, 0.71428571, 0.        ],
#        [1.        , 0.57142857, 1.        , 0.42857143],
#        [0.57142857, 0.        , 0.28571429, 0.85714286],
#        [0.71428571, 0.71428571, 1.        , 0.28571429],
#        [0.        , 0.28571429, 0.28571429, 0.85714286],
#        [0.57142857, 0.57142857, 0.71428571, 1.        ],
#        [0.85714286, 0.        , 0.14285714, 0.71428571],
#        [0.57142857, 0.28571429, 0.57142857, 0.14285714],
#        [0.71428571, 0.71428571, 0.57142857, 0.57142857],
#        [1.        , 0.        , 0.14285714, 0.57142857],
#        [0.14285714, 0.71428571, 0.28571429, 0.14285714],
#        [0.85714286, 0.28571429, 0.85714286, 0.28571429],
#        [0.71428571, 0.14285714, 0.        , 0.28571429],
#        [1.        , 0.57142857, 0.14285714, 0.71428571],
#        [0.71428571, 0.        , 1.        , 0.28571429],
#        [0.71428571, 0.42857143, 0.14285714, 0.14285714],
#        [0.85714286, 0.        , 0.85714286, 1.        ],
#        [0.28571429, 0.28571429, 0.14285714, 1.        ],
#        [0.85714286, 0.28571429, 0.85714286, 0.42857143],
#        [1.        , 0.57142857, 0.71428571, 1.        ],
#        [0.57142857, 0.        , 1.        , 0.14285714],
#        [0.57142857, 0.85714286, 0.85714286, 0.85714286],
#        [0.        , 0.        , 0.42857143, 0.        ],
#        [0.28571429, 0.42857143, 0.28571429, 0.42857143],
#        [0.85714286, 0.14285714, 0.        , 0.28571429],
#        [0.71428571, 0.71428571, 0.71428571, 0.42857143],
#        [0.57142857, 0.42857143, 1.        , 0.42857143],
#        [0.57142857, 0.71428571, 0.71428571, 0.57142857],
#        [0.42857143, 0.57142857, 1.        , 0.        ],
#        [0.14285714, 0.42857143, 0.57142857, 0.        ],
#        [1.        , 1.        , 0.14285714, 0.71428571],
#        [0.71428571, 0.85714286, 0.42857143, 0.        ],
#        [0.71428571, 0.57142857, 0.        , 0.42857143],
#        [0.42857143, 0.        , 0.85714286, 0.85714286],
#        [0.28571429, 0.71428571, 0.57142857, 0.14285714],
#        [0.28571429, 0.57142857, 0.        , 0.14285714],
#        [0.        , 0.57142857, 0.85714286, 0.14285714],
#        [0.57142857, 0.71428571, 0.71428571, 0.        ],
#        [0.85714286, 1.        , 0.57142857, 0.14285714],
#        [0.71428571, 0.57142857, 1.        , 0.57142857],
#        [0.85714286, 0.85714286, 0.42857143, 0.14285714],
#        [0.71428571, 0.85714286, 0.28571429, 0.14285714]])

# %%
import pandas as pd 
df = pd.DataFrame(data=myData, columns=['clmn1', 'clmn2', 'clmn3', 'labels']) 
df
# Out:
#     clmn1  clmn2  clmn3  labels
# 0       6      4      6       3
# 1       1      1      2       1
# 2       4      4      7       3
# 3       3      4      5       1
# 4       4      7      6       3
# 5       4      3      5       4
# 6       2      7      6       2
# 7       6      3      3       1
# 8       7      2      8       5
# 9       3      7      4       1
# 10      4      1      1       1
# 11      5      1      4       7
# 12      8      6      2       3
# 13      5      4      3       7
# 14      8      6      6       7
# 15      4      7      5       1
# 16      7      3      8       2
# 17      1      5      4       4
# 18      2      4      7       8
# 19      5      7      3       3
# 20      7      4      5       8
# 21      6      8      7       5
# 22      6      5      7       8
# 23      1      3      6       3
# 24      5      2      2       5
# 25      1      8      6       3
# 26      7      8      1       8
# 27      1      1      4       8
# 28      2      7      8       1
# 29      3      4      7       2
# ..    ...    ...    ...     ...
# 70      6      2      1       3
# 71      8      5      2       6
# 72      6      1      8       3
# 73      6      4      2       2
# 74      7      1      7       8
# 75      3      3      2       8
# 76      7      3      7       4
# 77      8      5      6       8
# 78      5      1      8       2
# 79      5      7      7       7
# 80      1      1      4       1
# 81      3      4      3       4
# 82      7      2      1       3
# 83      6      6      6       4
# 84      5      4      8       4
# 85      5      6      6       5
# 86      4      5      8       1
# 87      2      4      5       1
# 88      8      8      2       6
# 89      6      7      4       1
# 90      6      5      1       4
# 91      4      1      7       7
# 92      3      6      5       2
# 93      3      5      1       2
# 94      1      5      7       2
# 95      5      6      6       1
# 96      7      8      5       2
# 97      6      5      8       5
# 98      7      7      4       2
# 99      6      7      3       2
#
# [100 rows x 4 columns]

# %%
X = df[['clmn1', 'clmn2', 'clmn3']]
y = df['labels']

# %%
from sklearn.model_selection import train_test_split # consider this as validation
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)  #80percent  20 percent test
#X_train.shape
#X_test.shape
#y_train.shape
#y_test.shape

# %%
y_test
# Out:
# 1     1
# 36    7
# 37    6
# 83    4
# 82    3
# 84    4
# 86    1
# 88    6
# 97    5
# 15    1
# 29    2
# 28    1
# 66    5
# 73    2
# 41    1
# 65    2
# 77    8
# 16    2
# 5     4
# 90    4
# Name: labels, dtype: int32

# %%
from sklearn.linear_model import LinearRegression as lm
model=lm().fit(X_train,y_train)
predictions=model.predict(X_test)
import matplotlib.pyplot as plt
plt.xlabel('True values')
plt.ylabel('Predictions')
plt.scatter(y_test,predictions)

# %%
model
# Out:
# LinearRegression()

# %%
y_test
# Out:
# 1     1
# 36    7
# 37    6
# 83    4
# 82    3
# 84    4
# 86    1
# 88    6
# 97    5
# 15    1
# 29    2
# 28    1
# 66    5
# 73    2
# 41    1
# 65    2
# 77    8
# 16    2
# 5     4
# 90    4
# Name: labels, dtype: int32

# %%
predictions
# Out:
# array([3.66133893, 3.72340393, 4.53953484, 4.57916993, 5.06950563,
#        4.41713983, 4.12614943, 5.00261034, 4.60875003, 4.05693423,
#        3.94459423, 3.54416863, 4.58922493, 4.71877014, 3.35314334,
#        4.49699493, 5.11146063, 4.94943053, 4.25569463, 4.67913504])

# %%
import pandas as pd 
myData = np.random.randint(10, 99, (100 ,4)) # implement
myData # show the data
import pandas as pd 
df = pd.DataFrame(data=myData, columns=['clmn1', 'clmn2', 'clmn3', 'labels']) 
df.tail()
# Out:
#     clmn1  clmn2  clmn3  labels
# 95     45     88     11      92
# 96     69     92     91      65
# 97     90     31     21      98
# 98     83     74     41      16
# 99     64     26     14      34

# %%
df.max()
# Out:
# clmn1     97
# clmn2     98
# clmn3     98
# labels    98
# dtype: int32

# %%
df
# Out:
#     clmn1  clmn2  clmn3  labels
# 0      54     20     44      11
# 1      33     13     85      98
# 2      95     50     58      47
# 3      18     64     94      21
# 4      91     70     30      68
# 5      27     55     88      72
# 6      39     31     36      19
# 7      55     32     24      56
# 8      88     72     25      88
# 9      41     77     44      87
# 10     95     17     85      70
# 11     73     50     68      74
# 12     71     15     19      13
# 13     88     67     20      37
# 14     68     18     25      73
# 15     26     13     75      22
# 16     56     28     65      38
# 17     23     90     48      28
# 18     29     55     24      97
# 19     23     62     92      91
# 20     17     54     86      93
# 21     78     78     87      64
# 22     49     96     25      46
# 23     81     53     63      31
# 24     34     84     91      34
# 25     33     69     81      13
# 26     71     21     85      56
# 27     86     45     53      72
# 28     92     75     65      94
# 29     35     93     72      56
# ..    ...    ...    ...     ...
# 70     15     31     17      43
# 71     27     65     33      26
# 72     62     47     98      81
# 73     92     66     86      46
# 74     66     83     63      68
# 75     22     58     14      50
# 76     20     35     39      55
# 77     10     40     48      44
# 78     13     92     55      27
# 79     23     21     73      15
# 80     62     10     78      67
# 81     12     44     39      16
# 82     44     23     32      34
# 83     86     57     60      24
# 84     70     50     13      61
# 85     54     65     20      95
# 86     26     95     89      95
# 87     31     58     19      49
# 88     28     91     57      27
# 89     74     25     30      45
# 90     82     77     69      50
# 91     44     78     47      41
# 92     75     82     98      78
# 93     77     23     32      18
# 94     79     20     27      39
# 95     45     88     11      92
# 96     69     92     91      65
# 97     90     31     21      98
# 98     83     74     41      16
# 99     64     26     14      34
#
# [100 rows x 4 columns]

# %%
df.mean() # Returns the mean of all columns
df.corr() # Returns the correlation between columns in a data frame
df.count() # Returns the number of non-null values in each data frame column
df.max() # Returns the highest value in each column
df.min() # Returns the lowest value in each column
df.median() # Returns the median of each column
df.std() #Returns the standard deviation of each column
# Out:
# clmn1     25.464969
# clmn2     26.392184
# clmn3     27.265444
# labels    25.769444
# dtype: float64
