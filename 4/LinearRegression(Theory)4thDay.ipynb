# %% [raw]
# There are two types of supervised machine learning algorithms:
# Regression and classification.

# %% [raw]
# Important Definitions:
# 1. Variance
# variance is a measure of how far observed values differ from the average of predicted values, i.e., their difference from the predicted value mean. The goal is to have a value that is low. What low means is quantified by the r2 score
# 2. R2 Score
# R-squared values range from 0 to 1 and are commonly stated as percentages from 0% to 100%. R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination
#
# 3. Mean Squared Error(MSE)
# Mean Squared Error is the most commonly used regression loss function. MSE is the sum of squared distances between our target variable and predicted values.

# %% [raw]
# Linear regression performs the task to predict a "dependent"
# variable value (y) based on a given independent variable (x). So, this regression technique finds out a linear relationship between x (input) and y(output)

# %% [raw]
# y=wx+c

# %% [raw]
# your goal is: Finding the Best fitting line shown in the figure with Red color by finding w and c such that it minimize the MSE of linear model.

# %%
from IPython.display import Image
Image(filename='RegressionPic.png')

# %% [raw]
# Parameters are estimated from training data. (Remember you only teach your computer with training Data)
# The learning algorithm finds the parameters that optimize an objective(Remember basic polynomial from yesterday!) function, typically to minimize of loss function of the predicted target values vs. actual target values.

# %% [raw]
# Accuracy is one metric for evaluating classification models. Informally, accuracy is the fraction of predictions our model got right. Formally, accuracy has the following definition
#
# ACC= Number of Correct Predictions / Total Number of Predictions

# %% [raw]
# loss is a number indicating how bad the model's prediction was on a single example. If the model's prediction is perfect therefore the loss is zero; otherwise, the loss is greater. It looks like having a high variance problem because of the increasing gap between train and val parameters. Training with more data would help

# %%
from IPython.display import Image
Image(filename='overfit1.png')

# %% [raw]
# Gradient descent
# Gradient descent is an optimization algorithm used to minimize some function by iteratively moving in the direction of steepest descent as defined by the negative of the gradient. In machine learning, we use gradient descent to update the parameters of our model.

# %%
from IPython.display import Image
Image(filename='grad_descent1.gif')

# %% [raw]
# Polynomial Regression
# Generate new features consisting of all polynomial combinations of the original two features 𝑥0, 𝑥1 . The degree of the polynomial specifies how many variables participate at a time in each new feature (below example: degree 2). This is still a weighted linear combination of features, so it’s still a linear model and can use same least-squares estimation method for w and b.

# %%
from IPython.display import Image
Image(filename='polyRegression1.png')

# %%
from IPython.display import Image
Image(filename='over-underfit1.png')

# %% [raw]
# Ridge Regression
# Ridge regression is an extension of linear regression. It’s basically a regularized linear regression model. Ridge regression learns w, b using the same least-squares criterion but adds a penalty for large variations in w parameters
# The addition of a parameter penalty is called regularization.
# Regularization prevents overfitting by restricting the model, typically to reduce its complexity.
# Ridge regression uses L2 regularization: minimize the sum of squares of w entries.
# The influence of the regularization term is controlled by the 𝛼 parameter. Higher alpha means more regularization and simpler models.

# %% [raw]
# Important for many machine learning methods that all features are on the same scale (e.g. faster convergence in learning, more uniform or ‘fair’ influence for all weights)
# e.g. regularized regression, k-NN, support vector machines, neural networks, …
# example: MinMax Scaler
